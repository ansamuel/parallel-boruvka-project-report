# %% [markdown]
# # Presentation Plots

# %% [markdown]
# ## Imports

# %%
import os

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# IPython magic:

# %%
# %matplotlib inline
plt.rcParams["figure.dpi"] = 100
plt.style.use('seaborn-whitegrid')
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.size": 18
})
# %config InlineBackend.figure_formats = ['retina']

# %% [markdown]
# ## Constants

# %%
DATA_PATH = "data/"
FILES = os.listdir(DATA_PATH)
FILES_PATH = dict(zip([file.split('_')[-1][:-4] for  file in FILES],
                      [os.path.join(DATA_PATH, file) for file in FILES]))

# %%
FILES_PATH
# Out:
# {'weakscaling': 'data/s15-17_np1-16_weakscaling.csv',
#  'strongscaling': 'data/s19_np1-16_strongscaling.csv',
#  'growinggraph': 'data/s7-19_np8_growinggraph.csv'}

# %%
FIGSIZE = (8,6)

# %%
ALGORITHMS={
    0 : "EDGE DISTRIBUTED",
    1 : "EDGE DISTRIBUTED POINTER_JUMPING",
    2 : "VERTEX DISTRIBUTED",
    3 : "VERTEX DISTRIBUTED POINTER JUMPING",
    4 : "VERTEX DISTRIBUTED SUPERVERTICES POINTER JUMPING",
    5 : "BOOST (baseline)"}

# %%
def double_std(array):
    return np.std(array) * 2

# %% [markdown]
# ## 1. Strong Scaling

# %%
df_strongscaling = pd.read_csv(FILES_PATH['strongscaling'])
df_strongscaling.head(5)
# Out:
#    algorithm  cores       m1        m2        m3        m4        m5  \
# 0          0      1  0.70617  0.706512  0.704235  0.705656  0.703745
# 1          0      2  0.39650  0.397500  0.398200  0.398500  0.399300
# 2          0      4  0.32890  0.323200  0.303300  0.304600  0.304100
# 3          0      8  0.30710  0.300000  0.298900  0.289800  0.291100
# 4          0     16  0.43540  0.434400  0.432300  0.433200  0.432500
#
#          m6        m7        m8       m9       m10
# 0  0.705371  0.704514  0.706113  0.70471  0.706488
# 1  0.398300  0.398700  0.389600  0.38670  0.386600
# 2  0.305300  0.304900  0.304000  0.30560  0.304100
# 3  0.290600  0.289400  0.288800  0.28920  0.288800
# 4  0.434100  0.433900  0.432600  0.43290  0.432300

# %%
grouped_strongscaling = df_strongscaling.set_index(['algorithm', 'cores']).stack()
res_strongscaling = {alg : grouped_strongscaling[alg].groupby('cores').agg([np.mean, double_std]) for alg in set(df_strongscaling.algorithm)}

# %%
fig, ax = plt.subplots(figsize=FIGSIZE)

xticks = sorted(set(df_strongscaling.cores))
ax.set_xticks(xticks)
ax.set_xlim([min(xticks)-0.4, max(xticks)+0.4])
max_time = df_strongscaling.loc[:, 'm1':].to_numpy().max()
ax.set_yticks(np.arange(0, np.ceil(max_time), 0.5))
ax.set_ylim([0,np.mean([max_time,np.ceil(max_time)])])
for label in ax.yaxis.get_ticklabels()[1::2]:
    label.set_visible(False)

STYLES = {
    0 : dict(linestyle='-',color='blue', linewidth=1.5,marker='x',mfc='none',markersize=5),
    1 : None,
    2 : dict(linestyle='-.',color='black', linewidth=1),
    3 : dict(linestyle=':',color='black', linewidth=1),
    4 : dict(linestyle='--',color='black', linewidth=1),
    5 : dict(linestyle='-',color='red', linewidth=1.5)}

for alg in set(df_strongscaling.algorithm):
    x = res_strongscaling[alg].index
    y = res_strongscaling[alg]['mean']
    ax.errorbar(x, y, yerr=res_strongscaling[alg]['double_std'],label=ALGORITHMS[alg],**STYLES[alg],capsize=2);

ax.set(xlabel="Number of MPI processes",ylabel=r"Avg. time in $\mathrm{s}$",title=r"\textbf{Strong Scaling Study of Boruvka Implementations}")
legend = plt.legend(loc='upper right',bbox_to_anchor=(1.85,1), borderpad = 0)
legend._legend_box.align = "left"

del fig, ax, xticks, legend

# %% [markdown]
# ## 2. Weak Scaling

# %%
df_weakscaling = pd.read_csv(FILES_PATH['weakscaling'])
df_weakscaling
# Out:
#     algorithm  graph_size  cores        m1        m2        m3        m4  \
# 0           0          15      1  0.022837  0.022236  0.020819  0.020773
# 1           0          16      4  0.022900  0.020800  0.018000  0.018100
# 2           0          17     16  0.064100  0.064400  0.064300  0.064500
# 3           2          15      1  0.103341  0.103160  0.098166  0.098022
# 4           2          16      4  0.242100  0.235700  0.236400  0.233900
# 5           2          17     16  0.557800  0.551700  0.552900  0.552300
# 6           3          15      1  0.103384  0.103411  0.098508  0.098227
# 7           3          16      4  0.240600  0.238800  0.237200  0.238100
# 8           3          17     16  0.559700  0.553400  0.554300  0.552900
# 9           4          15      1  0.140025  0.138814  0.134131  0.132385
# 10          4          16      4  0.276100  0.268900  0.272300  0.271100
# 11          4          17     16  0.669800  0.669400  0.664300  0.676700
# 12          5          15      1  0.314973  0.314730  0.317066  0.315028
# 13          5          16      4  0.449800  0.450100  0.464000  0.455500
# 14          5          17     16  0.909300  0.921000  0.919200  0.920300
#
#           m5        m6        m7        m8        m9       m10
# 0   0.020807  0.020735  0.020781  0.020754  0.020704  0.020759
# 1   0.018000  0.018000  0.018200  0.018200  0.018200  0.018300
# 2   0.064800  0.064800  0.064700  0.064700  0.065100  0.064500
# 3   0.098281  0.098169  0.098083  0.098074  0.098221  0.098260
# 4   0.234300  0.234100  0.235200  0.235500  0.234100  0.234300
# 5   0.552100  0.552100  0.551500  0.553100  0.552300  0.552100
# 6   0.098123  0.098250  0.098240  0.098372  0.098343  0.098277
# 7   0.233700  0.236800  0.233700  0.238200  0.234000  0.238100
# 8   0.554300  0.552300  0.554400  0.551800  0.557600  0.560600
# 9   0.130591  0.132610  0.133996  0.133144  0.132229  0.132540
# 10  0.265200  0.268000  0.266000  0.269300  0.265500  0.268300
# 11  0.670700  0.664100  0.666900  0.657400  0.666000  0.662400
# 12  0.323078  0.322250  0.321770  0.322081  0.339728  0.323521
# 13  0.461900  0.448800  0.449200  0.440500  0.454800  0.454300
# 14  0.925600  0.922100  0.929300  0.928200  0.924200  0.923400

# %%
grouped_weakscaling = df_weakscaling.drop('graph_size', axis=1).set_index(['algorithm', 'cores']).stack()
res_weakscaling = {alg : grouped_weakscaling[alg].groupby('cores').agg([np.mean, double_std]) for alg in set(df_weakscaling.algorithm)}

# %%
fig, ax = plt.subplots(figsize=FIGSIZE)

ax.set_xticks(np.geomspace(1, 16, num=3))
ax.set_xlim([0.6, 16.4])
ax.set_yticks(np.arange(0, 10, 0.5))
ax.set_ylim([0,9.8])
for label in ax.yaxis.get_ticklabels()[1::2]:
    label.set_visible(False)

for alg in set(df_strongscaling.algorithm):
    x = res_weakscaling[alg].index
    y = res_weakscaling[alg]['mean']
    ax.errorbar(x, y, yerr=res_weakscaling[alg]['double_std'],label=ALGORITHMS[alg],**STYLES[alg],capsize=2);

ax.set(xlabel="(Number of MPI processes, $log_2$ of number of vertices)",ylabel=r"Avg. time in $\mathrm{s}$",title="$\mathbf{Weak\ Scaling\ Study\ of\ Boruvka\ Implementations}$")
legend = plt.legend(loc='upper right',bbox_to_anchor=(1.85,1), borderpad = 0)
legend._legend_box.align = "left"

del fig, ax, legend
